# %%
import numpy as np
import pandas as pd
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

# %%
#Drafient matrix
gradient = np.array([[.4,.2],[.2,1.0]])

# %%
#Starting point and two iterations
w0=np.array([[2,-2]])
w1=np.array([[1.6,-0.4]])
w2=np.array([[1.04,-0.32]])

# %%
#contour plot
x = np.outer(np.linspace(-5,5,201), np.ones(201))
y = x.copy().T
z = 2*(x**2)+2*x*y+5*(y**2)
fig, ax = plt.subplots(1,1)
ax.contour(x,y,z)
ax.set_title('Contour Plot')
ax.set_xlabel('w1')
ax.set_ylabel('w2')
plt.scatter(2,-2)
plt.scatter(1.6,-0.4)
plt.scatter(1.04,-0.32)
plt.legend(["w0","w1","w2"])
plt.show()
