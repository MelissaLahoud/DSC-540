# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from scipy import stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score

# %%
os.chdir("C:\\Users\\melis\\Documents\\DSC-540 Machine Learning")

Subject101 = pd.read_csv('subject101.dat', header = None, sep = '\s+')
Subject102 = pd.read_csv('subject102.dat', header = None, sep = '\s+')
Subject103 = pd.read_csv('subject103.dat', header = None, sep = '\s+')
Subject104 = pd.read_csv('subject104.dat', header = None, sep = '\s+')
Subject105 = pd.read_csv('subject105.dat', header = None, sep = '\s+')
Subject106 = pd.read_csv('subject106.dat', header = None, sep = '\s+')
Subject107 = pd.read_csv('subject107.dat', header = None, sep = '\s+')
Subject108 = pd.read_csv('subject108.dat', header = None, sep = '\s+')
Subject109 = pd.read_csv('subject109.dat', header = None, sep = '\s+')

# %%
#Create headings
df = []
frames = [Subject101, Subject102, Subject103, Subject104, Subject105, Subject106, Subject107, Subject108, Subject109]
df = pd.concat(frames, axis=0)
df.reset_index(drop=True, inplace=True)

df.columns = ['TimeStamp', 'Activity', 'HeartRate', 
              'HTemp', 'H01', 'H02', 'H03', 'H04', 'H05', 'H06', 'H07', 'H08', 'H09', 'H10', 'H11', 'H12', 'H13', 'H14', 'H15', 'H16',
             'CTemp', 'C01', 'C02', 'C03', 'C04', 'C05', 'C06', 'C07', 'C08', 'C09', 'C10', 'C11', 'C12', 'C13', 'C14', 'C15', 'C16',
             'ATemp', 'A01', 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08','A09', 'A10', 'A11', 'A12', 'A13', 'A14', 'A15', 'A16']

# %%
#eliminate missing data
HR = df.HeartRate
df = df.drop('HeartRate', axis = 1)
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2844868 entries, 0 to 2872532
# Data columns (total 53 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   TimeStamp  float64
#  1   Activity   int64
#  2   HTemp      float64
#  3   H01        float64
#  4   H02        float64
#  5   H03        float64
#  6   H04        float64
#  7   H05        float64
#  8   H06        float64
#  9   H07        float64
#  10  H08        float64
#  11  H09        float64
#  12  H10        float64
#  13  H11        float64
#  14  H12        float64
#  15  H13        float64
#  16  H14        float64
#  17  H15        float64
#  18  H16        float64
#  19  CTemp      float64
#  20  C01        float64
#  21  C02        float64
#  22  C03        float64
#  23  C04        float64
#  24  C05        float64
#  25  C06        float64
#  26  C07        float64
#  27  C08        float64
#  28  C09        float64
#  29  C10        float64
#  30  C11        float64
#  31  C12        float64
# ...

# %%
df['H01MA'] = df.H01.rolling(window=1000).mean()
df['H02MA'] = df.H02.rolling(window=1000).mean()
df['H03MA'] = df.H03.rolling(window=1000).mean()
df['H04MA'] = df.H04.rolling(window=1000).mean()
df['H05MA'] = df.H05.rolling(window=1000).mean()
df['H06MA'] = df.H06.rolling(window=1000).mean()
df['H07MA'] = df.H07.rolling(window=1000).mean()
df['H08MA'] = df.H08.rolling(window=1000).mean()
df['H09MA'] = df.H09.rolling(window=1000).mean()
df['H10MA'] = df.H10.rolling(window=1000).mean()
df['H11MA'] = df.H11.rolling(window=1000).mean()
df['H12MA'] = df.H12.rolling(window=1000).mean()
df['H13MA'] = df.H13.rolling(window=1000).mean()
df['H14MA'] = df.H14.rolling(window=1000).mean()
df['H15MA'] = df.H15.rolling(window=1000).mean()
df['H16MA'] = df.H16.rolling(window=1000).mean()

# %%
df['C01MA'] = df.C01.rolling(window=1000).mean()
df['C02MA'] = df.C02.rolling(window=1000).mean()
df['C03MA'] = df.C03.rolling(window=1000).mean()
df['C04MA'] = df.C04.rolling(window=1000).mean()
df['C05MA'] = df.C05.rolling(window=1000).mean()
df['C06MA'] = df.C06.rolling(window=1000).mean()
df['C07MA'] = df.C07.rolling(window=1000).mean()
df['C08MA'] = df.C08.rolling(window=1000).mean()
df['C09MA'] = df.C09.rolling(window=1000).mean()
df['C10MA'] = df.C10.rolling(window=1000).mean()
df['C11MA'] = df.C11.rolling(window=1000).mean()
df['C12MA'] = df.C12.rolling(window=1000).mean()
df['C13MA'] = df.C13.rolling(window=1000).mean()
df['C14MA'] = df.C14.rolling(window=1000).mean()
df['C15MA'] = df.C15.rolling(window=1000).mean()
df['C16MA'] = df.C16.rolling(window=1000).mean()

# %%
df['A01MA'] = df.A01.rolling(window=1000).mean()
df['A02MA'] = df.A02.rolling(window=1000).mean()
df['A03MA'] = df.A03.rolling(window=1000).mean()
df['A04MA'] = df.A04.rolling(window=1000).mean()
df['A05MA'] = df.A05.rolling(window=1000).mean()
df['A06MA'] = df.A06.rolling(window=1000).mean()
df['A07MA'] = df.A07.rolling(window=1000).mean()
df['A08MA'] = df.A08.rolling(window=1000).mean()
df['A09MA'] = df.A09.rolling(window=1000).mean()
df['A10MA'] = df.A10.rolling(window=1000).mean()
df['A11MA'] = df.A11.rolling(window=1000).mean()
df['A12MA'] = df.A12.rolling(window=1000).mean()
df['A13MA'] = df.A13.rolling(window=1000).mean()
df['A14MA'] = df.A14.rolling(window=1000).mean()
df['A15MA'] = df.A15.rolling(window=1000).mean()
df['A16MA'] = df.A16.rolling(window=1000).mean()

# %%
df['H01MA'] = stats.zscore(df['H01MA'])
df['H02MA'] = stats.zscore(df['H02MA'])
df['H03MA'] = stats.zscore(df['H03MA'])
df['H04MA'] = stats.zscore(df['H04MA'])
df['H05MA'] = stats.zscore(df['H05MA'])
df['H06MA'] = stats.zscore(df['H06MA'])
df['H07MA'] = stats.zscore(df['H07MA'])
df['H08MA'] = stats.zscore(df['H08MA'])
df['H09MA'] = stats.zscore(df['H09MA'])
df['H10MA'] = stats.zscore(df['H10MA'])
df['H11MA'] = stats.zscore(df['H11MA'])
df['H12MA'] = stats.zscore(df['H12MA'])
df['H13MA'] = stats.zscore(df['H13MA'])
df['H14MA'] = stats.zscore(df['H14MA'])
df['H15MA'] = stats.zscore(df['H15MA'])
df['H16MA'] = stats.zscore(df['H16MA'])

# %%
df['C01MA'] = stats.zscore(df['C01MA'])
df['C02MA'] = stats.zscore(df['C02MA'])
df['C03MA'] = stats.zscore(df['C03MA'])
df['C04MA'] = stats.zscore(df['C04MA'])
df['C05MA'] = stats.zscore(df['C05MA'])
df['C06MA'] = stats.zscore(df['C06MA'])
df['C07MA'] = stats.zscore(df['C07MA'])
df['C08MA'] = stats.zscore(df['C08MA'])
df['C09MA'] = stats.zscore(df['C09MA'])
df['C10MA'] = stats.zscore(df['C10MA'])
df['C11MA'] = stats.zscore(df['C11MA'])
df['C12MA'] = stats.zscore(df['C12MA'])
df['C13MA'] = stats.zscore(df['C13MA'])
df['C14MA'] = stats.zscore(df['C14MA'])
df['C15MA'] = stats.zscore(df['C15MA'])
df['C16MA'] = stats.zscore(df['C16MA'])

# %%
df['A01MA'] = stats.zscore(df['A01MA'])
df['A02MA'] = stats.zscore(df['A02MA'])
df['A03MA'] = stats.zscore(df['A03MA'])
df['A04MA'] = stats.zscore(df['A04MA'])
df['A05MA'] = stats.zscore(df['A05MA'])
df['A06MA'] = stats.zscore(df['A06MA'])
df['A07MA'] = stats.zscore(df['A07MA'])
df['A08MA'] = stats.zscore(df['A08MA'])
df['A09MA'] = stats.zscore(df['A09MA'])
df['A10MA'] = stats.zscore(df['A10MA'])
df['A11MA'] = stats.zscore(df['A11MA'])
df['A12MA'] = stats.zscore(df['A12MA'])
df['A13MA'] = stats.zscore(df['A13MA'])
df['A14MA'] = stats.zscore(df['A14MA'])
df['A15MA'] = stats.zscore(df['A15MA'])
df['A16MA'] = stats.zscore(df['A16MA'])

# %%
df = df.sample(frac= .0105)

# %%
df
# Out:
#          TimeStamp  Activity    HTemp        H01       H02       H03  \
# 1517270    1120.14        17  35.3750  -2.661960   0.87488  9.157260
# 996988     1741.35        12  32.1875 -18.824900  18.26250  4.584400
# 584663     2088.10         0  33.5625   4.950010   8.35448 -0.529743
# 126836     1276.74        16  33.6250   2.430580   3.07382 -3.474710
# 2793267    3378.31         7  30.8125   0.480005  -1.64021  2.246600
# ...            ...       ...      ...        ...       ...       ...
# 2512575     571.39         2  34.3750  -1.929560  -9.63966  0.851944
# 362765     3636.03         0  30.2500  -8.989860   5.21724  5.506990
# 1000711    1778.58        13  32.1250  -8.572620  -2.39913  2.767840
# 351670     3525.08        24  30.1875  -1.773860  -2.64429 -5.904610
# 1739508    3342.52         5  33.8125   6.774980   3.07899  0.900936
#
#                H04       H05       H06       H07  ...  A07MA  A08MA  A09MA  \
# ...

# %%
df = df.dropna()

# %%
df
# Out:
# Empty DataFrame
# Columns: [TimeStamp, Activity, HTemp, H01, H02, H03, H04, H05, H06, H07, H08, H09, H10, H11, H12, H13, H14, H15, H16, CTemp, C01, C02, C03, C04, C05, C06, C07, C08, C09, C10, C11, C12, C13, C14, C15, C16, ATemp, A01, A02, A03, A04, A05, A06, A07, A08, A09, A10, A11, A12, A13, A14, A15, A16, H01MA, H02MA, H03MA, H04MA, H05MA, H06MA, H07MA, H08MA, H09MA, H10MA, H11MA, H12MA, H13MA, H14MA, H15MA, H16MA, C01MA, C02MA, C03MA, C04MA, C05MA, C06MA, C07MA, C08MA, C09MA, C10MA, C11MA, C12MA, C13MA, C14MA, C15MA, C16MA, A01MA, A02MA, A03MA, A04MA, A05MA, A06MA, A07MA, A08MA, A09MA, A10MA, A11MA, A12MA, A13MA, A14MA, A15MA, ...]
# Index: []
#
# [0 rows x 101 columns]

# %%
y = df.Activity
X = df[['H01MA', 'H02MA', 'H03MA', 'H04MA', 'H05MA', 'H06MA', 'H07MA', 'H08MA', 
       'H09MA', 'H10MA', 'H11MA', 'H12MA', 'H13MA', 'H14MA', 'H15MA', 'H16MA', 
       'C01MA', 'C02MA', 'C03MA', 'C04MA', 'C05MA', 'C06MA', 'C07MA', 'C08MA', 
       'C09MA', 'C10MA', 'C11MA', 'C12MA', 'C13MA', 'C14MA', 'C15MA', 'C16MA', 
       'A01MA', 'A02MA', 'A03MA', 'A04MA', 'A05MA', 'A06MA', 'A07MA', 'A08MA', 
       'A09MA', 'A10MA', 'A11MA', 'A12MA', 'A13MA', 'A14MA', 'A15MA', 'A16MA']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=0)

# %%
#Random Forest

rf = RandomForestClassifier(n_estimators = 100, criterion="gini").fit(X_train,y_train)
ypred = rf.predict(X_test)
C1 = pd.crosstab(y_test, ypred, rownames=['Actual'], colnames=['Predicted'])
C1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-d5642bdfa562> in <module>
#       1 #Random Forest
#       2
# ----> 3 rf = RandomForestClassifier(n_estimators = 100, criterion="gini").fit(X_train,y_train)
#       4 ypred = rf.predict(X_test)
#       5 ConfMat = pd.crosstab(y_test, ypred,
#
# ~\Documents\Anaconda\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     301                 "sparse multilabel-indicator for y is not supported."
#     302             )
# --> 303         X, y = self._validate_data(X, y, multi_output=True,
#     304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#
# ~\Documents\Anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
f1_score(y_test, ypred, average = 'macro')

# %%
#bagging
bag = BaggingClassifier(KNeighborsClassifier(), max_samples=0.5, max_features=0.5).fit(X_train, y_train)

# %%
ypred2 = bagging.predict(X_test)
C2 = pd.crosstab(y_test, ypred2, rownames=['Actual'], colnames=['Predicted'])
C2

# %%
f1_score(y_test, ypred02, average = 'macro')

# %%
#knn
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train,y_train)

# %%
ypred3 = knn.predict(X_test)
C3 = pd.crosstab(y_test, ypred3,rownames=['Actual'], colnames=['Predicted'])
C3

# %%
#SVM
model = SVC(kernel='linear')
model.fit(X_train,y_train)

# %%
ypred4 = model.predict(X_test)
C4 = pd.crosstab(y_test, ypred4,rownames=['Actual'], colnames=['Predicted'])
C4

# %%
#Weighted average
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
model1 = DecisionTreeClassifier()
model2 = KNeighborsClassifier()
model3= LogisticRegression()

model1.fit(X_train,y_train)
model2.fit(X_train,y_train)
model3.fit(X_train,y_train)

pred1=model1.predict_proba(x_test)
pred2=model2.predict_proba(x_test)
pred3=model3.predict_proba(x_test)

finalpred=(pred1*0.3+pred2*0.3+pred3*0.4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-57bb12181624> in <module>
#       6 model3= LogisticRegression()
#       7
# ----> 8 model1.fit(X_train,y_train)
#       9 model2.fit(X_train,y_train)
#      10 model3.fit(X_train,y_train)
#
# ~\Documents\Anaconda\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# ~\Documents\Anaconda\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     155             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 156             X, y = self._validate_data(X, y,
# ...

# %%
#Boosting
model = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, 
                                 max_depth=1, random_state=0).fit(X_train, y_train)
model.score(X_test, y_test)

# %%
ypred5 = model.predict(X_test)
C5 = pd.crosstab(y_test, ypred5, rownames=['Actual'], colnames=['Predicted'])
C5
